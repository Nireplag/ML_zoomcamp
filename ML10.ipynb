# %% [markdown]
# <a href="https://colab.research.google.com/github/Nireplag/ML_zoomcamp/blob/main/ML10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1 :
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 2:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 3:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 4:
#
# kind load docker-image zoomcamp-model:hw10

# %% [markdown]
# Question 5 AND 6

# %%
apiVersion: apps/v1
kind: Deployment
metadata:
  name: credit
spec:
  selector:
    matchLabels:
      app: credit
  replicas: 1
  template:
    metadata:
      labels:
        app: credit
    spec:
      containers:
        - name: credit
          image: zoomcamp-model:hw10
          resources:
            requests:
              memory: '64Mi'
              cpu: '100m'
            limits:
              memory: '800Mi'
              cpu: '500m'
          ports:
            - containerPort: 9696

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
apiVersion: v1
kind: Service
metadata:
  name: credit
spec:
  type: LoadBalancer
  selector:
    app: credit
  ports:
    - port: 80
      targetPort: 9696

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
